# %%
from pyspark.sql import functions as f
def new_columns_insertion(df):
    return (df.withColumn("ingestion_timestamp", f.current_timestamp())
                     .withColumn("source_file", f.col("_metadata.file_path"))
                     )
