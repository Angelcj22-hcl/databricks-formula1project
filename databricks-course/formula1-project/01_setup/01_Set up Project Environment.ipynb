-- %% [markdown]
-- # Set up the Project Environment for Formula1 Project
-- 1. Create External location databricks-course-extt-dl30-formula1
-- 2. Create Catalog formula1
-- 3. Create Schemas landing,bronze,silver and gold
-- 4. Create Volume files in landing schema

-- %% [markdown]
-- Access Cloud Storage

-- %%
%fs ls 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/'

-- %% [markdown]
-- Create External Location

-- %%
CREATE EXTERNAL LOCATION databricks_course_extt_dl30_formula1
URL 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-course-sc`)
COMMENT 'External location for formula container';

-- %%
SHOW CATALOGS;

-- %%
CREATE CATALOG IF NOT EXISTS formula1
    MANAGED LOCATION 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/' 
    COMMENT 'This is the main catalog for formula1';

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.landing;

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.bronze
MANAGED LOCATION 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS formula1.silver
MANAGED LOCATION 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS formula1.gold
MANAGED LOCATION 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/gold';

-- %%
USE CATALOG formula1;
show schemas;

-- %%
CREATE EXTERNAL VOLUME formula1.landing.files
LOCATION 'abfss://formula1@databrickscourseexttdl30.dfs.core.windows.net/landing';
