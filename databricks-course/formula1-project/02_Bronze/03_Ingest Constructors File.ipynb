# %% [markdown]
# #Ingest the Races csv file
# 1. Read the file using spark DataframeReader API
# 2. Add metadata columns
#    - Source File
#    - Ingestion Timestamp
# 3. Write to Bronze Delta Tables

# %% [markdown]
# ### Read the CSV using Spark Dataframe API

# %%
# %run ../00_common/01_environment_config

# %%
# %run ../00_common/02_bronze_helpers

# %%
table_name = f"{catalog_name}.{bronze_schema}.constructors"
source_file = f"{landing_folder_path}/constructors.json"

# %%
constructors_schema= """constructorId STRING, 
                        name STRING, 
                        nationality STRING,
                        url STRING"""

# %%
constructors_df=(
    spark.read
    .format("json")
    #.option("header","True")
    #.option("inferSchema", "True")
    .option("mode", "FAILFAST")
    .schema(constructors_schema)
    .load(source_file))

# %%
display(constructors_df)

# %% [markdown]
# ### Adding 2 new colums
# - Source File
# - Ingestion Timestamp

# %%
constructors_final_df = new_columns_insertion(constructors_df)
display(constructors_final_df)

# %%
(constructors_final_df
.write
.format("delta")
.mode("overwrite")
.saveAsTable(table_name))

# %%
display(spark.table(table_name))
