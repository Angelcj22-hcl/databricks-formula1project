# %% [markdown]
# #Create Catalog and Schema for Demo
#
# ####Catalog : demo
# ####
# Schema : delta_lake

# %%
# %sql
CREATE CATALOG IF NOT EXISTS demo
MANAGED LOCATION 'abfss://demo@databrickscourseexttdl30.dfs.core.windows.net/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS demo.delta_lake
MANAGED LOCATION 'abfss://demo@databrickscourseexttdl30.dfs.core.windows.net/delta_lake'

# %%
# %sql
CREATE TABLE IF NOT EXISTS demo.delta_lake.companies
(
    company_name STRING,
    founded_date DATE,
    country STRING

)
