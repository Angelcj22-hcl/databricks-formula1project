-- %%
%fs ls 'abfss://demo@databrickscourseexttdl30.dfs.core.windows.net/'

-- %%
CREATE EXTERNAL LOCATION databricks_course_extt_dl30_demo
URL 'abfss://demo@databrickscourseexttdl30.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-course-sc`)
COMMENT 'External location for demo container';
